# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://www-us.apache.org/dist/spark/spark-2.4.7/spark-2.4.7-bin-hadoop2.6.tgz
# !tar xf spark-2.4.7-bin-hadoop2.6.tgz
# !pip install -q findspark

# %%
# !pyspark --version
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 2.3.2
#       /_/
#
# Using Scala version 2.11.8, OpenJDK 64-Bit Server VM, 11.0.9.1
# Branch
# Compiled by user jshao on 2018-09-16T11:51:52Z
# Revision
# Url
# Type --help for more information.

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.7-bin-hadoop2.6"

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
# !pip install pyspark==2.3.2
# Out:
# Requirement already satisfied: pyspark==2.3.2 in /usr/local/lib/python3.6/dist-packages (2.3.2)
# Requirement already satisfied: py4j==0.10.7 in /usr/local/lib/python3.6/dist-packages (from pyspark==2.3.2) (0.10.7)

# %%
# !pyspark --packages graphframes:graphframes:0.7.0-spark2.3-s_2.11 --jars graphframes-0.7.0-spark2.3-s_2.11.jar
# Out:
# Python 3.6.9 (default, Oct  8 2020, 12:12:24)
# [GCC 8.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# :: loading settings :: url = jar:file:/content/spark-2.4.7-bin-hadoop2.6/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# graphframes#graphframes added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-a97bffbf-031e-4721-a270-33432d2f48ae;1.0
# 	confs: [default]
# 	found graphframes#graphframes;0.7.0-spark2.3-s_2.11 in spark-packages
# 	found org.slf4j#slf4j-api;1.7.16 in central
# :: resolution report :: resolve 321ms :: artifacts dl 6ms
# 	:: modules in use:
# 	graphframes#graphframes;0.7.0-spark2.3-s_2.11 from spark-packages in [default]
# 	org.slf4j#slf4j-api;1.7.16 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   2   |   0   |   0   |   0   ||   2   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-a97bffbf-031e-4721-a270-33432d2f48ae
# 	confs: [default]
# 	0 artifacts copied, 2 already retrieved (0kB/8ms)
# 20/11/22 01:00:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# 20/11/22 01:00:30 WARN DependencyUtils: Local jar /content/graphframes-0.7.0-spark2.3-s_2.11.jar does not exist, skipping.
# 20/11/22 01:00:31 INFO SparkContext: Running Spark version 2.4.7
# 20/11/22 01:00:31 INFO SparkContext: Submitted application: PySparkShell
# 20/11/22 01:00:31 INFO SecurityManager: Changing view acls to: root
# 20/11/22 01:00:31 INFO SecurityManager: Changing modify acls to: root
# 20/11/22 01:00:31 INFO SecurityManager: Changing view acls groups to:
# 20/11/22 01:00:31 INFO SecurityManager: Changing modify acls groups to:
# 20/11/22 01:00:31 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(root); groups with view permissions: Set(); users  with modify permissions: Set(root); groups with modify permissions: Set()
# 20/11/22 01:00:31 INFO Utils: Successfully started service 'sparkDriver' on port 44177.
# 20/11/22 01:00:31 INFO SparkEnv: Registering MapOutputTracker
# 20/11/22 01:00:31 INFO SparkEnv: Registering BlockManagerMaster
# 20/11/22 01:00:31 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 20/11/22 01:00:31 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 20/11/22 01:00:31 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-b4d01d76-5eca-4db1-bb49-0f9ac77f0397
# 20/11/22 01:00:32 INFO MemoryStore: MemoryStore started with capacity 366.3 MB
# 20/11/22 01:00:32 INFO SparkEnv: Registering OutputCommitCoordinator
# 20/11/22 01:00:32 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 20/11/22 01:00:32 INFO Utils: Successfully started service 'SparkUI' on port 4041.
# 20/11/22 01:00:32 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://e233a71940b9:4041
# 20/11/22 01:00:32 ERROR SparkContext: Failed to add file:/content/graphframes-0.7.0-spark2.3-s_2.11.jar to Spark environment
# java.io.FileNotFoundException: Jar /content/graphframes-0.7.0-spark2.3-s_2.11.jar not found
# 	at org.apache.spark.SparkContext.addJarFile$1(SparkContext.scala:1838)
# 	at org.apache.spark.SparkContext.addJar(SparkContext.scala:1868)
# 	at org.apache.spark.SparkContext$$anonfun$12.apply(SparkContext.scala:458)
# 	at org.apache.spark.SparkContext$$anonfun$12.apply(SparkContext.scala:458)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at org.apache.spark.SparkContext.<init>(SparkContext.scala:458)
# 	at org.apache.spark.api.java.JavaSparkContext.<init>(JavaSparkContext.scala:58)
# 	at sun.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# 	at sun.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
# 	at sun.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:423)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:238)
# 	at py4j.commands.ConstructorCommand.invokeConstructor(ConstructorCommand.java:80)
# 	at py4j.commands.ConstructorCommand.execute(ConstructorCommand.java:69)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
# 20/11/22 01:00:32 INFO SparkContext: Added JAR file:///root/.ivy2/jars/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar at spark://e233a71940b9:44177/jars/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar with timestamp 1606006832396
# 20/11/22 01:00:32 INFO SparkContext: Added JAR file:///root/.ivy2/jars/org.slf4j_slf4j-api-1.7.16.jar at spark://e233a71940b9:44177/jars/org.slf4j_slf4j-api-1.7.16.jar with timestamp 1606006832397
# 20/11/22 01:00:32 INFO SparkContext: Added file file:///root/.ivy2/jars/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar at file:///root/.ivy2/jars/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar with timestamp 1606006832433
# 20/11/22 01:00:32 INFO Utils: Copying /root/.ivy2/jars/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar to /tmp/spark-687cfc24-1e73-47c8-9c0c-85a6a0894e83/userFiles-3ea7d76e-5348-4662-bc38-d35aad872bae/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar
# 20/11/22 01:00:32 INFO SparkContext: Added file file:///root/.ivy2/jars/org.slf4j_slf4j-api-1.7.16.jar at file:///root/.ivy2/jars/org.slf4j_slf4j-api-1.7.16.jar with timestamp 1606006832459
# 20/11/22 01:00:32 INFO Utils: Copying /root/.ivy2/jars/org.slf4j_slf4j-api-1.7.16.jar to /tmp/spark-687cfc24-1e73-47c8-9c0c-85a6a0894e83/userFiles-3ea7d76e-5348-4662-bc38-d35aad872bae/org.slf4j_slf4j-api-1.7.16.jar
# 20/11/22 01:00:32 INFO Executor: Starting executor ID driver on host localhost
# 20/11/22 01:00:32 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 38013.
# 20/11/22 01:00:32 INFO NettyBlockTransferService: Server created on e233a71940b9:38013
# 20/11/22 01:00:32 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 20/11/22 01:00:32 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, e233a71940b9, 38013, None)
# 20/11/22 01:00:32 INFO BlockManagerMasterEndpoint: Registering block manager e233a71940b9:38013 with 366.3 MB RAM, BlockManagerId(driver, e233a71940b9, 38013, None)
# 20/11/22 01:00:32 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, e233a71940b9, 38013, None)
# 20/11/22 01:00:32 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, e233a71940b9, 38013, None)
# 20/11/22 01:00:33 INFO SharedState: Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir ('file:/content/spark-warehouse').
# 20/11/22 01:00:33 INFO SharedState: Warehouse path is 'file:/content/spark-warehouse'.
# 20/11/22 01:00:33 INFO StateStoreCoordinatorRef: Registered StateStoreCoordinator endpoint
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.4.7
#       /_/
#
# Using Python version 3.6.9 (default, Oct  8 2020 12:12:24)
# SparkSession available as 'spark'.
# >>> exit()
# 20/11/22 01:00:39 INFO SparkUI: Stopped Spark web UI at http://e233a71940b9:4041
# 20/11/22 01:00:39 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 20/11/22 01:00:39 INFO MemoryStore: MemoryStore cleared
# 20/11/22 01:00:39 INFO BlockManager: BlockManager stopped
# 20/11/22 01:00:39 INFO BlockManagerMaster: BlockManagerMaster stopped
# 20/11/22 01:00:39 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 20/11/22 01:00:39 INFO SparkContext: Successfully stopped SparkContext
# 20/11/22 01:00:39 INFO ShutdownHookManager: Shutdown hook called
# 20/11/22 01:00:39 INFO ShutdownHookManager: Deleting directory /tmp/spark-fda13237-b43c-4111-8744-2a354eb9e2e9
# 20/11/22 01:00:39 INFO ShutdownHookManager: Deleting directory /tmp/spark-687cfc24-1e73-47c8-9c0c-85a6a0894e83
# 20/11/22 01:00:39 INFO ShutdownHookManager: Deleting directory /tmp/spark-687cfc24-1e73-47c8-9c0c-85a6a0894e83/pyspark-d06aa2ec-29e6-4943-afca-efb7bd1649ea

# %%
# !cp /root/.ivy2/jars/* /content/spark-2.4.7-bin-hadoop2.6/jars

# %%
# !pyspark --packages graphframes:graphframes:0.7.0-spark2.3-s_2.11 --jars graphframes-0.7.0-spark2.3-s_2.11.jar
# Out:
# Python 3.6.9 (default, Oct  8 2020, 12:12:24)
# [GCC 8.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# :: loading settings :: url = jar:file:/content/spark-2.4.7-bin-hadoop2.6/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# graphframes#graphframes added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-a52d27c8-eafe-45e6-a179-592367474321;1.0
# 	confs: [default]
# 	found graphframes#graphframes;0.7.0-spark2.3-s_2.11 in spark-packages
# 	found org.slf4j#slf4j-api;1.7.16 in central
# :: resolution report :: resolve 353ms :: artifacts dl 7ms
# 	:: modules in use:
# 	graphframes#graphframes;0.7.0-spark2.3-s_2.11 from spark-packages in [default]
# 	org.slf4j#slf4j-api;1.7.16 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   2   |   0   |   0   |   0   ||   2   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-a52d27c8-eafe-45e6-a179-592367474321
# 	confs: [default]
# 	0 artifacts copied, 2 already retrieved (0kB/8ms)
# 20/11/22 01:00:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# 20/11/22 01:00:46 WARN DependencyUtils: Local jar /content/graphframes-0.7.0-spark2.3-s_2.11.jar does not exist, skipping.
# 20/11/22 01:00:47 INFO SparkContext: Running Spark version 2.4.7
# 20/11/22 01:00:47 INFO SparkContext: Submitted application: PySparkShell
# 20/11/22 01:00:47 INFO SecurityManager: Changing view acls to: root
# 20/11/22 01:00:47 INFO SecurityManager: Changing modify acls to: root
# 20/11/22 01:00:47 INFO SecurityManager: Changing view acls groups to:
# 20/11/22 01:00:47 INFO SecurityManager: Changing modify acls groups to:
# 20/11/22 01:00:47 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(root); groups with view permissions: Set(); users  with modify permissions: Set(root); groups with modify permissions: Set()
# 20/11/22 01:00:47 INFO Utils: Successfully started service 'sparkDriver' on port 40395.
# 20/11/22 01:00:47 INFO SparkEnv: Registering MapOutputTracker
# 20/11/22 01:00:47 INFO SparkEnv: Registering BlockManagerMaster
# 20/11/22 01:00:47 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 20/11/22 01:00:47 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 20/11/22 01:00:47 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-4efaeaea-434f-48ce-bdd6-cf964983d3ff
# 20/11/22 01:00:47 INFO MemoryStore: MemoryStore started with capacity 366.3 MB
# 20/11/22 01:00:47 INFO SparkEnv: Registering OutputCommitCoordinator
# 20/11/22 01:00:48 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 20/11/22 01:00:48 INFO Utils: Successfully started service 'SparkUI' on port 4041.
# 20/11/22 01:00:48 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://e233a71940b9:4041
# 20/11/22 01:00:48 ERROR SparkContext: Failed to add file:/content/graphframes-0.7.0-spark2.3-s_2.11.jar to Spark environment
# java.io.FileNotFoundException: Jar /content/graphframes-0.7.0-spark2.3-s_2.11.jar not found
# 	at org.apache.spark.SparkContext.addJarFile$1(SparkContext.scala:1838)
# 	at org.apache.spark.SparkContext.addJar(SparkContext.scala:1868)
# 	at org.apache.spark.SparkContext$$anonfun$12.apply(SparkContext.scala:458)
# 	at org.apache.spark.SparkContext$$anonfun$12.apply(SparkContext.scala:458)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at org.apache.spark.SparkContext.<init>(SparkContext.scala:458)
# 	at org.apache.spark.api.java.JavaSparkContext.<init>(JavaSparkContext.scala:58)
# 	at sun.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# 	at sun.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
# 	at sun.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:423)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:238)
# 	at py4j.commands.ConstructorCommand.invokeConstructor(ConstructorCommand.java:80)
# 	at py4j.commands.ConstructorCommand.execute(ConstructorCommand.java:69)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
# 20/11/22 01:00:48 INFO SparkContext: Added JAR file:///root/.ivy2/jars/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar at spark://e233a71940b9:40395/jars/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar with timestamp 1606006848326
# 20/11/22 01:00:48 INFO SparkContext: Added JAR file:///root/.ivy2/jars/org.slf4j_slf4j-api-1.7.16.jar at spark://e233a71940b9:40395/jars/org.slf4j_slf4j-api-1.7.16.jar with timestamp 1606006848327
# 20/11/22 01:00:48 INFO SparkContext: Added file file:///root/.ivy2/jars/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar at file:///root/.ivy2/jars/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar with timestamp 1606006848358
# 20/11/22 01:00:48 INFO Utils: Copying /root/.ivy2/jars/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar to /tmp/spark-3e03377e-2f82-4d7f-885c-ccd3a49caf6e/userFiles-362ece4a-04a9-4804-80e9-f91ff47dac26/graphframes_graphframes-0.7.0-spark2.3-s_2.11.jar
# 20/11/22 01:00:48 INFO SparkContext: Added file file:///root/.ivy2/jars/org.slf4j_slf4j-api-1.7.16.jar at file:///root/.ivy2/jars/org.slf4j_slf4j-api-1.7.16.jar with timestamp 1606006848388
# 20/11/22 01:00:48 INFO Utils: Copying /root/.ivy2/jars/org.slf4j_slf4j-api-1.7.16.jar to /tmp/spark-3e03377e-2f82-4d7f-885c-ccd3a49caf6e/userFiles-362ece4a-04a9-4804-80e9-f91ff47dac26/org.slf4j_slf4j-api-1.7.16.jar
# 20/11/22 01:00:48 INFO Executor: Starting executor ID driver on host localhost
# 20/11/22 01:00:48 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 43989.
# 20/11/22 01:00:48 INFO NettyBlockTransferService: Server created on e233a71940b9:43989
# 20/11/22 01:00:48 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 20/11/22 01:00:48 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, e233a71940b9, 43989, None)
# 20/11/22 01:00:48 INFO BlockManagerMasterEndpoint: Registering block manager e233a71940b9:43989 with 366.3 MB RAM, BlockManagerId(driver, e233a71940b9, 43989, None)
# 20/11/22 01:00:48 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, e233a71940b9, 43989, None)
# 20/11/22 01:00:48 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, e233a71940b9, 43989, None)
# 20/11/22 01:00:49 INFO SharedState: Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir ('file:/content/spark-warehouse').
# 20/11/22 01:00:49 INFO SharedState: Warehouse path is 'file:/content/spark-warehouse'.
# 20/11/22 01:00:49 INFO StateStoreCoordinatorRef: Registered StateStoreCoordinator endpoint
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.4.7
#       /_/
#
# Using Python version 3.6.9 (default, Oct  8 2020 12:12:24)
# SparkSession available as 'spark'.
# >>> exit()
# 20/11/22 01:00:54 INFO SparkUI: Stopped Spark web UI at http://e233a71940b9:4041
# 20/11/22 01:00:54 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 20/11/22 01:00:54 INFO MemoryStore: MemoryStore cleared
# 20/11/22 01:00:54 INFO BlockManager: BlockManager stopped
# 20/11/22 01:00:54 INFO BlockManagerMaster: BlockManagerMaster stopped
# 20/11/22 01:00:54 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 20/11/22 01:00:54 INFO SparkContext: Successfully stopped SparkContext
# 20/11/22 01:00:54 INFO ShutdownHookManager: Shutdown hook called
# 20/11/22 01:00:54 INFO ShutdownHookManager: Deleting directory /tmp/spark-e67f181a-656c-43e7-b25b-8546ca6e0f63
# 20/11/22 01:00:54 INFO ShutdownHookManager: Deleting directory /tmp/spark-3e03377e-2f82-4d7f-885c-ccd3a49caf6e
# 20/11/22 01:00:54 INFO ShutdownHookManager: Deleting directory /tmp/spark-3e03377e-2f82-4d7f-885c-ccd3a49caf6e/pyspark-114d5ac7-c4ff-464e-93cb-4b2f624e4c37

# %%
import pyspark
import pandas as pd

# %%
# sc = pyspark.SparkContext(appName="GraphApp")

# %%
df = pd.read_csv('/content/drive/MyDrive/Twitter-Dataset-Analysis/295B/Nov21/neo4j_dataset.csv')

# %%
df.head(5)
# Out:
#    user_id  weights    followers  ...  sf_score  followers_weights  final_weights
# 0   1084.0     0.65   20245031.0  ...      0.15               1.10           1.75
# 1   1084.0     0.65   24909650.0  ...      0.10               1.05           1.70
# 2   1084.0     0.65    6409352.0  ...      0.15               1.05           1.70
# 3   1084.0     0.65  422386163.0  ...      0.15               1.05           1.70
# 4   1084.0     0.65  209754177.0  ...      0.15               1.05           1.70
#
# [5 rows x 19 columns]

# %%
len(df)
# Out:
# 16370

# %%
nodes = []
for index, row in df.iterrows():
        nodes.append(row['user_id'])
        nodes.append(row['followers'])

# %%
nodes = list(set(nodes))

# %%
df = pd.DataFrame (nodes,columns=['Nodes'])

# %%
df['id'] = df.index

# %%
df.head(5)
# Out:
#           Nodes  id
# 0  7.507331e+17   0
# 1  7.181759e+17   1
# 2  1.487667e+07   2
# 3  8.222404e+17   3
# 4  8.580792e+17   4

# %%
df[df['id'] == 1688]
# Out:
#            Nodes    id
# 1688  86773118.0  1688

# %%
# df.to_csv('/content/drive/My Drive/Twitter-Dataset-Analysis/295B/Nodes_table.csv',index=False)

# %%
# df = spark.createDataFrame(df)

# %%
main_df = pd.read_csv('/content/drive/MyDrive/Twitter-Dataset-Analysis/295B/Nov21/neo4j_dataset.csv')

# %%
# main_df['relationship'] = 'Followed by'
main_df['relationship'] = main_df['final_weights']

# %%
main_df.columns
# Out:
# Index(['user_id', 'weights', 'followers', 'foll_following', 'foll_follower',
#        'foll_isVerified', 'foll_favouritesCount', 'foll_statusCount',
#        'foll_profileTime', 'active_years', 'status_followers_ratio',
#        'followers_following_ratio', 'verified_score', 'active_year_score',
#        'ff_score', 'favorites_count_score', 'sf_score', 'followers_weights',
#        'final_weights', 'relationship'],
#       dtype='object')

# %%
main_df = main_df.drop(columns=['weights', 'foll_following', 'foll_follower',
       'foll_isVerified', 'foll_favouritesCount', 'foll_statusCount',
       'foll_profileTime', 'active_years', 'status_followers_ratio',
       'followers_following_ratio', 'verified_score', 'active_year_score',
       'ff_score', 'favorites_count_score', 'sf_score', 'followers_weights',
       'final_weights'])

# %%
main_df = main_df.rename(columns={'user_id':'src','followers':'dst'})
main_df
# Out:
#               src           dst  relationship
# 0          1084.0  2.024503e+07          1.75
# 1          1084.0  2.490965e+07          1.70
# 2          1084.0  6.409352e+06          1.70
# 3          1084.0  4.223862e+08          1.70
# 4          1084.0  2.097542e+08          1.70
# ...           ...           ...           ...
# 16365  38540813.0  1.460288e+09          1.20
# 16366  38540813.0  2.750106e+09          1.20
# 16367  38540813.0  4.743222e+09          1.20
# 16368  38540813.0  1.682157e+09          1.20
# 16369  38540813.0  2.354356e+07          1.20
#
# [16370 rows x 3 columns]

# %%
main_df.to_csv('/content/drive/My Drive/Twitter-Dataset-Analysis/295B/Edges_table.csv',index=False)

# %%
# main_df= spark.createDataFrame(main_df)

# %%
 #!pip install graphframes
# Out:
# Requirement already satisfied: graphframes in /usr/local/lib/python3.6/dist-packages (0.6)
# Requirement already satisfied: nose in /usr/local/lib/python3.6/dist-packages (from graphframes) (1.3.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from graphframes) (1.18.5)

# %%
from graphframes import GraphFrame

# %%
from pyspark.sql import SQLContext
sqlCtx = SQLContext(sparkContext=spark.sparkContext, sparkSession=spark)

# %%
sdf = sqlCtx.createDataFrame(df)
mdf = sqlCtx.createDataFrame(main_df)

# %%
g = GraphFrame(sdf, mdf)

# %%
## Take a look at the DataFrames
g.vertices.show()
# Out:
# +--------------------+---+
# |               Nodes| id|
# +--------------------+---+
# |7.507330902055977E17|  0|
# |7.181758632131297...|  1|
# |         1.4876674E7|  2|
# |8.222404107894784E17|  3|
# |8.580791690239672...|  4|
# |9.262008067889561...|  5|
# |1.014042087501660...|  6|
# |8.350620928351273E17|  7|
# |7.283460296957624...|  8|
# |7.413270082028175...|  9|
# |        1.12263169E8| 10|
# |        1.69639941E8| 11|
# |         2.1331977E7| 12|
# |       1.613070343E9| 13|
# |        4.64781327E8| 14|
# |           7766032.0| 15|
# |         2.9392914E7| 16|
# |        3.51600659E8| 17|
# |        3.48160018E8| 18|
# |       1.053098006E9| 19|
# +--------------------+---+
# only showing top 20 rows

# %%
g.edges.show()
# Out:
# +------+-------------+------------------+
# |   src|          dst|      relationship|
# +------+-------------+------------------+
# |1084.0|  2.0245031E7|              1.75|
# |1084.0|   2.490965E7|1.7000000000000002|
# |1084.0|    6409352.0|1.7000000000000002|
# |1084.0| 4.22386163E8|               1.7|
# |1084.0| 2.09754177E8|               1.7|
# |1084.0|  1.9617447E7|              1.65|
# |1084.0|  3.8025393E7|              1.65|
# |1084.0| 2.16912174E8|              1.65|
# |1084.0|  2.4246497E7|              1.65|
# |1084.0| 3.26610928E8|              1.65|
# |1084.0| 3.20524842E8|              1.65|
# |1084.0|    1.43704E7|               1.6|
# |1084.0|  1.6015561E7|               1.6|
# |1084.0|  2.6265033E7|               1.6|
# |1084.0| 2.02465898E8|               1.6|
# |1084.0|      67313.0|               1.6|
# |1084.0|1.050389954E9|              1.55|
# |1084.0|2.297072474E9|              1.55|
# |1084.0|  7.1518255E7|1.4500000000000002|
# |1084.0|  9.5966813E7|1.4500000000000002|
# +------+-------------+------------------+
# only showing top 20 rows

# %%
## Check the number of edges of each vertex
g.degrees.show(1000)
# Out:
# +--------------------+------+
# |                  id|degree|
# +--------------------+------+
# |9.280454176478453...|     1|
# |        1.70523573E8|     1|
# |          4.735681E7|     1|
# |        1.63121789E8|     1|
# |            712843.0|     2|
# |            786560.0|   224|
# |         2.7902805E7|     1|
# |        1.18462326E8|     1|
# |          6.774138E7|     1|
# |         1.8537735E8|     1|
# |        3.23372931E8|     1|
# |         2.6885023E7|     1|
# |        2.66230149E8|     1|
# |         3.5677075E7|     1|
# |         2.1227034E7|     1|
# |         1.9193525E7|     1|
# |        1.02961213E8|     1|
# |         3.2330442E7|     1|
# |         8.8935531E7|     1|
# |         6.2295413E7|     1|
# |        4.97964297E8|     1|
# |         1.6175706E7|     1|
# |         7.5706571E7|     1|
# |         2.7942447E7|     1|
# |        1.38232124E8|     1|
# |       1.912260727E9|     1|
# |        2.70289872E8|     1|
# |         4.1207283E7|     1|
# |         3.7378408E7|     1|
# |        3.18439705E8|     1|
# |         1.9617105E7|     1|
# |         5.7543258E7|     1|
# |         1.8627174E7|    24|
# |         2.5594518E7|     1|
# |         2.3974217E7|     1|
# |        3.77481181E8|     1|
# |        1.01386226E8|     1|
# |        9.72814446E8|     1|
# |         2.8693889E7|     1|
# |         2.1477848E7|     1|
# |        2.42349423E8|     1|
# |       1.963839914E9|     1|
# |       1.597829942E9|     1|
# |         8.1522346E7|     1|
# |       1.507269835E9|     1|
# |          9.010777E7|     1|
# |         6.1149653E7|     2|
# |           5.13265E7|     1|
# |        4.38890032E8|     1|
# |         1.5004756E7|     1|
# |         1.8344575E7|     1|
# |         1.4435027E7|     1|
# |       1.525285584E9|     1|
# |        2.28804748E8|     1|
# |        4.23560041E8|     1|
# |         4.5123759E7|     1|
# |8.273618011928903...|     1|
# |8.088789463014441E17|     1|
# |         1.6559223E7|     1|
# |         1.4161311E7|     1|
# |         1.4058316E7|     1|
# |           3801141.0|     1|
# |         1.4029242E7|     1|
# |         1.6205388E8|     1|
# |         1.7072461E7|     1|
# |          5.310613E7|     1|
# |       3.266848117E9|     1|
# |       3.018960919E9|     1|
# |        1.58446462E8|     1|
# |         6.2788388E7|     1|
# |         2.8612267E7|     1|
# |         1.5972116E7|     1|
# |         2.7714725E7|     1|
# |        2.58664809E8|     1|
# |        1.24469485E8|     1|
# |        2.42266352E8|     1|
# |       4.786581027E9|     1|
# |       2.947732005E9|     1|
# |        3.17037769E8|     1|
# |        3.50323902E8|     1|
# +--------------------+------+
# only showing top 1000 rows

# %%
inDegreeDF=g.inDegrees

# %%
inDegreeDF.sort(['inDegree'],ascending=[0]).show()
# Out:
# +--------------------+--------+
# |                  id|inDegree|
# +--------------------+--------+
# |         3.3923443E7|       6|
# |          1.521067E7|       6|
# |       1.933042237E9|       5|
# |        3.79690254E8|       5|
# |8.562880024354201...|       5|
# |         4.3107187E8|       5|
# |         4.0317995E8|       5|
# |         4.3196616E7|       5|
# |         5.8569413E7|       5|
# |        2.92929271E8|       4|
# |         9.1942071E7|       4|
# |         1.8082945E7|       4|
# |           5548212.0|       4|
# |        1.39295156E9|       4|
# |         2.6735842E7|       4|
# |           5514192.0|       4|
# |         1.7717593E7|       4|
# |          1.680158E7|       4|
# |         5.4523519E8|       4|
# |         3.3611715E7|       4|
# +--------------------+--------+
# only showing top 20 rows

# %%
PageRankResults = g.pageRank(resetProbability=0.15, tol=0.01)

# %%
PageRankResults.vertices.sort(['pagerank'],ascending=[0]).show(50)
# Out:
# +-------------+-----+------------------+
# |        Nodes|   id|          pagerank|
# +-------------+-----+------------------+
# | 1.86197243E8| 4598|1.0437887284507785|
# |   1.737714E7| 4908|1.0030913557593428|
# |  2.3695723E7| 2185|1.0015350431870518|
# |4.787783837E9| 9008|1.0015350431870518|
# |  1.5766383E7| 2426| 1.001276241521492|
# |  9.3409572E7|10038|1.0011339006054343|
# | 1.47436328E8| 6401|0.9967213322076399|
# |1.038431071E9| 6424|0.9967213322076399|
# | 4.52100948E8|  418|0.9967213322076399|
# |  1.5439882E7| 3009|0.9967213322076399|
# | 1.12919665E8|  558|0.9967213322076399|
# |  8.8836072E7| 1010|0.9967213322076399|
# |1.242270145E9| 1224|0.9967213322076399|
# |  2.3194588E8| 6834|0.9967213322076399|
# |  2.1137969E7| 1277|0.9967213322076399|
# |  7.4615519E7| 1360|0.9967213322076399|
# |  2.0254407E7| 1840|0.9967213322076399|
# | 3.09563727E8| 2173|0.9967213322076399|
# |  3.1102566E7| 2812|0.9967213322076399|
# |  3.0807811E7| 2895|0.9967213322076399|
# |  3.0480141E7| 2906|0.9967213322076399|
# |  2.7637542E7| 6892|0.9967213322076399|
# |  4.9336117E8| 3015|0.9967213322076399|
# |  4.2866795E7| 3061|0.9967213322076399|
# |  2.7039968E7| 3106|0.9967213322076399|
# |1.6785615E7|       2.182536108E9|              1.55|              0.0125|
# |1.6786966E7|        3.38660808E8|              1.55|  0.0136986301369863|
# |1.7053094E7|         4.2644546E7|              1.65|0.012658227848101266|
# |1.7830383E7|7.055397633491640...|              1.15| 0.01020408163265306|
# |1.8365203E7|         3.9797871E7|               1.4|0.005208333333333333|
# |1.9152095E7|           8157452.0|1.2000000000000002|               0.005|
# |1.9152095E7|         2.0151409E7|               1.1|               0.005|
# |1.9152095E7|       2.562977786E9|               1.1|               0.005|
# |1.9408148E7|         2.7720385E7|               1.3|0.014285714285714285|
# |1.9408187E7|         1.9419315E7|1.2000000000000002| 0.00398406374501992|
# |1.9408187E7|         1.0662731E8|              1.15| 0.00398406374501992|
# |1.9413876E7|         1.5190357E7|               1.1|0.004587155963302...|
# |1.9664367E7|         1.3597528E8|               1.3|0.002906976744186...|
# |1.9672966E7|         6.5991738E7|              1.25|0.002427184466019...|
# |1.9672966E7|        4.07465636E8|               1.3|0.002427184466019...|
# |2.0197657E7|         1.7983365E7|              1.65|0.003745318352059925|
# |2.0197657E7|          1.913685E7|               1.3|0.003745318352059925|
# |  2.09842E7|        4.84926333E8|              1.15|0.002793296089385475|
# |2.1235814E7|         4.4301489E7|               1.4|0.005882352941176...|
# |2.1235814E7|        5.32239654E8|              1.25|0.005882352941176...|
# |2.1237884E7|        4.77565316E8|1.2500000000000002|0.002645502645502...|
# |2.1503693E7|       1.870177394E9|               1.2|0.013888888888888888|
# |2.1507276E7|        1.82634029E8|               1.6|0.013333333333333334|
# |2.2024242E7|       4.833408145E9|               1.3|0.002666666666666...|
# |2.2550338E7|         2.5954099E7|              1.35|0.005813953488372093|
# |2.2550338E7|         4.6934022E7|               1.4|0.005813953488372093|
# |2.2818119E7|        1.88830363E8|               1.1|0.005154639175257732|
# +-----------+--------------------+------------------+--------------------+
# only showing top 50 rows

# %%
result = g.labelPropagation(maxIter=5)

result.sort(['label'],ascending=[0]).show()
# Out:
# +-------------+-----+---------+
# |        Nodes|   id|    label|
# +-------------+-----+---------+
# | 3.66160489E8| 5242|211456485|
# |  2.1235814E7| 1084| 59931188|
# | 3.29159493E8| 2405| 23397973|
# | 1.91849753E8|12514| 19247128|
# |  9.3409572E7|10038| 18365203|
# |  8.6773118E7| 1688| 15324650|
# | 1.86197243E8| 4598| 14942880|
# |   1.737714E7| 4908|  5768872|
# | 9.62723839E8|15767|    15767|
# |  3.9878654E7|15766|    15766|
# | 5.22420221E8|15765|    15765|
# |  8.5229564E7|15764|    15764|
# |  5.0397179E7|15763|    15763|
# | 4.25230329E8|15762|    15762|
# |  3.8535159E7|15761|    15761|
# | 3.17226991E8|15760|    15760|
# |    2.11681E7|15759|    15759|
# |  4.4466147E7|15758|    15758|
# |3.293118434E9|15757|    15757|
# |1.499955164E9|15756|    15756|
# +-------------+-----+---------+
# only showing top 20 rows

# %%
result_df = result.toPandas()

# %%
print(len(set(result_df['label'])))
# Out:
# 15767

# %%
result.sort(['label'],ascending=[0]).show(50)
# Out:
# +-------------+-----+---------+
# |        Nodes|   id|    label|
# +-------------+-----+---------+
# | 3.66160489E8| 5242|211456485|
# |  2.1235814E7| 1084| 59931188|
# | 3.29159493E8| 2405| 23397973|
# | 1.91849753E8|12514| 19247128|
# |  9.3409572E7|10038| 18365203|
# |  8.6773118E7| 1688| 15324650|
# | 1.86197243E8| 4598| 14942880|
# |   1.737714E7| 4908|  5768872|
# | 9.62723839E8|15767|    15767|
# |  3.9878654E7|15766|    15766|
# | 5.22420221E8|15765|    15765|
# |  8.5229564E7|15764|    15764|
# |  5.0397179E7|15763|    15763|
# | 4.25230329E8|15762|    15762|
# |  3.8535159E7|15761|    15761|
# | 3.17226991E8|15760|    15760|
# |    2.11681E7|15759|    15759|
# |  4.4466147E7|15758|    15758|
# |3.293118434E9|15757|    15757|
# |1.499955164E9|15756|    15756|
# |  1.7367006E7|15755|    15755|
# | 2.21609949E8|15754|    15754|
# |  2.3452054E8|15753|    15753|
# | 4.01833947E8|15752|    15752|
# |  1.6449496E7|15751|    15751|
# | 1.60923608E8|15750|    15750|
# |  5.5672791E7|15749|    15749|
# |  1.6603541E8|15748|    15748|
# | 2.00081361E8|15747|    15747|
# | 2.98614737E8|15746|    15746|
# |1.647673296E9|15745|    15745|
# |  5.4722511E7|15744|    15744|
# |  1.2189642E7|15743|    15743|
# |  1.8218955E7|15742|    15742|
# |  2.0643785E7|15741|    15741|
# |  5.1904457E7|15740|    15740|
# | 2.40913607E9|15739|    15739|
# |   6.999239E7|15738|    15738|
# |  8.4049859E7|15737|    15737|
# |  1.6121795E7|15736|    15736|
# |  4.9315774E7|15735|    15735|
# |   4.220512E7|15734|    15734|
# |  5.6721343E7|15733|    15733|
# |  2.1594046E7|15732|    15732|
# | 1.95329977E8|15731|    15731|
# |  7.3727927E7|15730|    15730|
# |  2.8409779E7|15729|    15729|
# | 2.64241072E8|15728|    15728|
# | 2.77020589E8|15727|    15727|
# |1.857257388E9|15726|    15726|
# +-------------+-----+---------+
# only showing top 50 rows

# %%
result_scc = g.stronglyConnectedComponents(maxIter=25)
result_scc.show()
# Out:
# +-------------+----+---------+
# |        Nodes|  id|component|
# +-------------+----+---------+
# | 8.98465831E8|  26|       26|
# |  1.5826992E7|  29|       29|
# |     623543.0| 474|      474|
# |1.108477836E9| 964|      964|
# |  2.9461871E7|1677|     1677|
# |1.416334724E9|1697|     1697|
# |  1.6715398E7|1806|     1806|
# | 3.52685974E8|1950|     1950|
# | 1.18263866E8|2040|     2040|
# | 1.42578095E8|2214|     2214|
# | 7.13626099E8|2250|     2250|
# | 1.06632088E8|2453|     2453|
# |    7214092.0|2509|     2509|
# | 5.76623689E8|2529|     2529|
# |  2.2550338E7|2927|     2927|
# |  2.8711102E7|3091|     3091|
# | 1.30915361E8|3506|     3506|
# |1.539284516E9|3764|     3764|
# |  4.0707306E7|4590|     4590|
# |  5.4732477E7|4823|     4823|
# +-------------+----+---------+
# only showing top 20 rows

# %%
result_scc=result_scc.toPandas()
len(result_scc)
# Out:
# 15768
