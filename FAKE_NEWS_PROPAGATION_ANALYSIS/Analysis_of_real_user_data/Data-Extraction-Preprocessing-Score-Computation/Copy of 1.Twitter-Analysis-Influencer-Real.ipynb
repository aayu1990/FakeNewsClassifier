# %%
import os
import glob
import json
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Twitter-Dataset-Analysis/295B/Nov22/finalRealTweets.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,2,4,8,9,17,18,19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(5)
# Out:
#                        created_at  ... quoted_status
# 0  Sun Jul 22 16:31:58 +0000 2018  ...           NaN
# 1  Sun Jul 22 08:22:51 +0000 2018  ...           NaN
# 2  Tue Nov 20 17:46:08 +0000 2018  ...           NaN
# 3  Sun Mar 13 19:07:38 +0000 2016  ...           NaN
# 4  Sat Nov 10 14:05:05 +0000 2018  ...           NaN
#
# [5 rows x 28 columns]

# %%
df = df[df['user'].notna()]

# %%
df
# Out:
#                            created_at  ... quoted_status
# 0      Sun Jul 22 16:31:58 +0000 2018  ...           NaN
# 1      Sun Jul 22 08:22:51 +0000 2018  ...           NaN
# 2      Tue Nov 20 17:46:08 +0000 2018  ...           NaN
# 3      Sun Mar 13 19:07:38 +0000 2016  ...           NaN
# 4      Sat Nov 10 14:05:05 +0000 2018  ...           NaN
# ...                               ...  ...           ...
# 69628  Wed Oct 10 15:22:36 +0000 2018  ...           NaN
# 69629  Fri Apr 06 19:06:17 +0000 2018  ...           NaN
# 69630  Tue Oct 16 19:25:32 +0000 2018  ...           NaN
# 69631  Thu Nov 02 03:30:05 +0000 2017  ...           NaN
# 69632  Tue May 22 04:17:08 +0000 2018  ...           NaN
#
# [37206 rows x 28 columns]

# %%
df_userdetails = pd.DataFrame(df['user'])
df_userdetails
# Out:
#                                                     user
# 0      {'id': 833964896404508672, 'id_str': '83396489...
# 1      {'id': 14111628, 'id_str': '14111628', 'name':...
# 2      {'id': 205971568, 'id_str': '205971568', 'name...
# 3      {'id': 128762218, 'id_str': '128762218', 'name...
# 4      {'id': 44385059, 'id_str': '44385059', 'name':...
# ...                                                  ...
# 69628  {'id': 19812221, 'id_str': '19812221', 'name':...
# 69629  {'id': 539699081, 'id_str': '539699081', 'name...
# 69630  {'id': 710555609771298817, 'id_str': '71055560...
# 69631  {'id': 254165243, 'id_str': '254165243', 'name...
# 69632  {'id': 25950286, 'id_str': '25950286', 'name':...
#
# [37206 rows x 1 columns]

# %%
userIdArr = []
userFollowerArr = []
userFollowingArr = []
userStatusArr = []
userCreatedAtArr = []
userFavoriteCntArr = []
userVerifiedArr = []

# %%
for i, j in df_userdetails.iterrows(): 
#     userDictArry.append(eval(j))
    user = eval(j['user'])
#     print(i)
    userIdArr.append(user['id'])
    userFollowerArr.append(user['followers_count'])
    userFollowingArr.append(user['friends_count'])
    userStatusArr.append(user['statuses_count'])
    userCreatedAtArr.append(user['created_at'])
    userFavoriteCntArr.append(user['favourites_count'])
    userVerifiedArr.append(user['verified'])

# %%
print(len(userIdArr),len(userFollowerArr),len(userFollowingArr),len(userStatusArr),len(userCreatedAtArr),len(userFavoriteCntArr),len(userVerifiedArr))
# Out:
# 37206 37206 37206 37206 37206 37206 37206

# %%
twitter_list = [userIdArr,userFollowerArr,userFollowingArr,userStatusArr,userCreatedAtArr,userFavoriteCntArr,userVerifiedArr]

new_df = pd.DataFrame (twitter_list).transpose()
new_df.columns = ['user_id','followers_count','following_count','status_count','created_at','favorites_count','verified']
print (new_df)
# Out:
#                   user_id followers_count  ... favorites_count verified
# 0      833964896404508672             880  ...            1343    False
# 1                14111628            3981  ...             903    False
# 2               205971568            2359  ...            3044    False
# 3               128762218            1126  ...             181    False
# 4                44385059             835  ...            8209    False
# ...                   ...             ...  ...             ...      ...
# 37201            19812221            3445  ...            8453    False
# 37202           539699081            6155  ...          261841    False
# 37203  710555609771298817            1095  ...            7468    False
# 37204           254165243            1384  ...            1570    False
# 37205            25950286              74  ...             179    False
#
# [37206 rows x 7 columns]

# %%
new_df.to_csv('/content/drive/MyDrive/Twitter-Dataset-Analysis/295B/Nov22/RealNewsTweetUser_Nov22.csv',index=False)
