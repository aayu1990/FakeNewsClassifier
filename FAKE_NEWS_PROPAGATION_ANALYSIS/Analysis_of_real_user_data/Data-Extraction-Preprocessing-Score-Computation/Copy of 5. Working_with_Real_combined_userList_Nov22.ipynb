# %%
import pandas as pd
import ast

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Twitter-Dataset-Analysis/295B/Nov22/Real_combined_user_followerList_Nov22.csv')
df = df.head(300)

# %%
df.columns
# Out:
# Index(['user_id', 'weights', 'followers'], dtype='object')

# %%
new_df = pd.DataFrame(columns = ['user_id', 'weights', 'followers'])

# %%
for index, row in df.iterrows():
    followerCount = len(row['followers'])
    for i in ast.literal_eval(row['followers']):
#         print(i)
        new_df = new_df.append({'user_id':row['user_id'],'weights':row['weights'],'followers':i },ignore_index = True)

# %%
new_df
# Out:
#              user_id  weights     followers
# 0       1.688000e+03     0.95  7.966981e+17
# 1       1.688000e+03     0.95  4.387802e+07
# 2       1.688000e+03     0.95  1.358510e+07
# 3       1.688000e+03     0.95  5.018518e+07
# 4       1.688000e+03     0.95  1.707405e+08
# ...              ...      ...           ...
# 703774  2.345672e+09     0.40  2.237833e+09
# 703775  2.345672e+09     0.40  9.676593e+07
# 703776  2.345672e+09     0.40  2.249275e+09
# 703777  2.345672e+09     0.40  5.116609e+07
# 703778  2.345672e+09     0.40  2.276531e+09
#
# [703779 rows x 3 columns]

# %%
new_df.to_csv('/content/drive/MyDrive/Twitter-Dataset-Analysis/295B/Nov22/Real_user-follower-weighted_300_Nov22.csv',index=False)
