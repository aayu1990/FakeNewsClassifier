# %%
import pandas as pd
import ast

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Twitter-Dataset-Analysis/295B/Nov09/combined_user_followerList_Nov09.csv')
df = df.head(300)

# %%
df.columns
# Out:
# Index(['user_id', 'weights', 'followers'], dtype='object')

# %%
new_df = pd.DataFrame(columns = ['user_id', 'weights', 'followers'])

# %%
for index, row in df.iterrows():
    followerCount = len(row['followers'])
    for i in ast.literal_eval(row['followers']):
#         print(i)
        new_df = new_df.append({'user_id':row['user_id'],'weights':row['weights'],'followers':i },ignore_index = True)

# %%
new_df
# Out:
#            user_id  weights     followers
# 0           1084.0     0.65  8.207108e+17
# 1           1084.0     0.65  5.692212e+06
# 2           1084.0     0.65  2.892513e+07
# 3           1084.0     0.65  2.384755e+07
# 4           1084.0     0.65  1.189936e+07
# ...            ...      ...           ...
# 616578  50600050.0     0.55  2.114459e+08
# 616579  50600050.0     0.55  1.301184e+08
# 616580  50600050.0     0.55  1.962046e+08
# 616581  50600050.0     0.55  1.422288e+08
# 616582  50600050.0     0.55  1.487375e+07
#
# [616583 rows x 3 columns]

# %%
new_df.to_csv('/content/drive/My Drive/Twitter-Dataset-Analysis/295B/Nov09/user-follower-weighted_300_Nov11.csv',index=False)
