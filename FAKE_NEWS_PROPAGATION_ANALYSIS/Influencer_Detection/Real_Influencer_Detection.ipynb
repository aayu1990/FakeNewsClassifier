# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from scipy.stats import mode

# %%
df = pd.read_csv('/content/drive/MyDrive/Twitter-Dataset-Analysis/295B/Nov25/Centrality_Measures_Real.csv')

# %%
df
# Out:
#                Node  ...  Closeness Centrality
# 0      7.670000e+02  ...              0.177435
# 1      1.077000e+03  ...              0.177435
# 2      1.495000e+03  ...              0.169863
# 3      1.644000e+03  ...              0.161985
# 4      1.688000e+03  ...              0.199126
# ...             ...  ...                   ...
# 16068  1.200000e+18  ...              0.119835
# 16069  1.210000e+18  ...              0.501916
# 16070  1.210000e+18  ...              0.132428
# 16071  1.210000e+18  ...              0.137853
# 16072  1.210000e+18  ...              0.172126
#
# [16073 rows x 5 columns]

# %%
df = df.sort_values(by=['Page Rank','Betweenness Centrality','Closeness Centrality'], ascending=False)
df.head(400)
# Out:
#                Node  ...  Closeness Centrality
# 6217   5.741936e+07  ...              0.207910
# 1736   1.625552e+07  ...              0.203535
# 14080  1.426072e+09  ...              1.000000
# 13157  6.278459e+08  ...              0.128132
# 12574  4.548265e+08  ...              1.000000
# ...             ...  ...                   ...
# 11327  3.351611e+08  ...              0.157484
# 15348  2.866076e+09  ...              0.165757
# 14331  1.724613e+09  ...              0.180788
# 2309   1.741888e+07  ...              0.179477
# 8780   1.646984e+08  ...              0.179477
#
# [400 rows x 5 columns]

# %%
df.to_excel('/content/drive/MyDrive/Twitter-Dataset-Analysis/295B/Nov25/Real_Top20_Influencers.xlsx',index=False)
